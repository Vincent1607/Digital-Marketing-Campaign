# %%
import pandas as pd
import joblib

# %%
model = joblib.load('pipe.joblib')

# %%
dummy = {
    'Customer_ID': [8000, 8763, 7890, 1847, 9123],
    'Age': [29, 52, 60, 55, 19],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Female'],
    'Income': [136912, 41760, 88456, 123045, 24567],
    'CampaignChannel': ['Sosial Media', 'Email', 'PPC', 'Referral', 'SEO'],
    'CampaignType': ['Awareness', 'Retention', 'Conversion', 'Consideration', 'Conversion'],
    'AdSpend': [6497.87006842, 3898.51860568, 1548.3295958, 2476.10635405, 7743.6261702],
    'ClickThroughRate': [0.04391851, 0.15572507, 0.27749037, 0.05652592, 0.02396129],
    'ConversionRate': [0.04391851, 0.15572507, 0.27749037, 0.05652592, 0.02396129],
    'WebsiteVisits': [20, 37, 0, 63, 17],
    'PagesPerVisit': [2.39901653, 2.91713775, 8.2236191, 1.00296447, 6.96473936],
    'TimeOnSite': [3.87662337, 12.76365976, 14.61832341, 5.3525486, 2.834172],
    'SocialShares': [83, 33, 27, 1, 9],
    'EmailOpens': [6, 17, 3, 20, 11],
    'EmailClicks': [2, 5, 6, 9, 1],
    'PreviousPurchases': [7, 3, 5, 4, 9],
    'LoyaltyPoints': [1737, 932, 877, 4678, 189],
    'AdvertisingPlatform': ['IsConfid', 'IsConfid', 'IsConfid', 'IsConfid', 'IsConfid'],
    'AdvertisingTool': ['ToolConfid', 'ToolConfid', 'ToolConfid', 'ToolConfid', 'ToolConfid']
}

# %%
df = pd.DataFrame(dummy)

# %%
df
# Out:
#    Customer_ID  Age  Gender  Income CampaignChannel   CampaignType  \
# 0         8000   29    Male  136912    Sosial Media      Awareness
# 1         8763   52  Female   41760           Email      Retention
# 2         7890   60    Male   88456             PPC     Conversion
# 3         1847   55  Female  123045        Referral  Consideration
# 4         9123   19  Female   24567             SEO     Conversion
#
#        AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 0  6497.870068          0.043919        0.043919             20
# 1  3898.518606          0.155725        0.155725             37
# 2  1548.329596          0.277490        0.277490              0
# 3  2476.106354          0.056526        0.056526             63
# 4  7743.626170          0.023961        0.023961             17
#
#    PagesPerVisit  TimeOnSite  SocialShares  EmailOpens  EmailClicks  \
# 0       2.399017    3.876623            83           6            2
# ...

# %%
df_predict = model.predict(df)

# %%
for predicted in df_predict:
    if predicted == 0:
        print('tertarik')
    else:
        print('tidak tertarik')
# Out:
# tidak tertarik
# tidak tertarik
# tidak tertarik
# tidak tertarik
# tidak tertarik
